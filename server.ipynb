# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip3 install kaolin -f https://nvidia-kaolin.s3.us-east-2.amazonaws.com/torch-2.4.1_cu124.html
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 55.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 50.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 MB 6.8 MB/s eta 0:00:00
# ...

# %%
# !pip3 install pyngrok ninja
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 15.4 MB/s eta 0:00:00
# ...

# %%
# !ngrok config add-authtoken 2uWzHMUgtWC5Srkl5EUwMmJAEcG_6xnTvmVThPbFQ134sGqtL
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !git clone --recurse-submodules https://github.com/SunfiboAIDev/Image_to_CAD.git '/content/drive/MyDrive/Img_to_CAD/'
# Out:
# Cloning into '/content/drive/MyDrive/Img_to_CAD'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 282 (delta 69), reused 263 (delta 62), pack-reused 0 (from 0)
# Receiving objects: 100% (282/282), 33.65 MiB | 15.38 MiB/s, done.
# Resolving deltas: 100% (69/69), done.
# Updating files: 100% (179/179), done.
# Submodule 'trellis/representations/mesh/flexicubes' (https://github.com/MaxtirError/FlexiCubes.git) registered for path 'trellis/representations/mesh/flexicubes'
# Cloning into '/content/drive/MyDrive/Img_to_CAD/trellis/representations/mesh/flexicubes'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 69 (delta 29), reused 62 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 16.87 MiB | 11.98 MiB/s, done.
# ...

# %%
# !python /content/drive/MyDrive/Img_to_CAD/app.py
# Out:
# [SPARSE] Backend: spconv, Attention: xformers
# Warp 1.6.2 initialized:
#    CUDA Toolkit 12.8, Driver 12.4
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "Tesla T4" (15 GiB, sm_75, mempool enabled)
#    Kernel cache:
#      /root/.cache/warp/1.6.2
# /usr/local/lib/python3.11/dist-packages/gradio_client/utils.py:1097: UserWarning: file() is deprecated and will be removed in a future version. Use handle_file() instead.
#   warnings.warn(
# [SPARSE][CONV] spconv algo: auto
# [ATTENTION] Using backend: xformers
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# ...
